# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
import sys, os
sys.path.append(os.path.abspath(os.path.join('..')))
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
cities
# Out:
# 641
# ['rikitea',
#  'albany',
#  'lebu',
#  'bethel',
#  'manturovo',
#  'punta arenas',
#  'bacuit',
#  'tura',
#  'narsaq',
#  'chokurdakh',
#  'bluff',
#  'sentyabrskiy',
#  'tiarei',
#  'jiddah',
#  'ushuaia',
#  'cape town',
#  'puerto ayora',
#  'lorengau',
#  'grand river south east',
#  'wladyslawowo',
#  'jalpatagua',
#  'tuktoyaktuk',
#  'hokitika',
#  'hermanus',
#  'chuy',
#  'ulladulla',
#  'alugan',
#  'kavaratti',
#  'kieta',
#  'horsham',
#  'vaini',
#  'coria',
#  'mount gambier',
#  'morondava',
#  'airai',
#  'sydney',
#  'dudinka',
#  'saint-philippe',
#  'sioux lookout',
#  'port elizabeth',
#  'ribeira grande',
#  'sitka',
#  'vesoul',
#  'rock sound',
#  'avarua',
#  'nome',
#  'gweta',
#  'belushya guba',
#  'victoria',
#  'severo-kurilsk',
#  'mataura',
#  'sibu',
#  'zheleznodorozhnyy',
#  'tasiilaq',
#  'acari',
#  'inderborskiy',
#  'agadez',
#  'nizhneyansk',
#  'umzimvubu',
#  'tessalit',
#  'dingle',
#  'mar del plata',
#  'merauke',
#  'padang',
#  'kapaa',
#  'progreso',
#  'ambilobe',
#  'sao filipe',
#  'machico',
#  'abu samrah',
#  'new norfolk',
#  'bluffton',
#  'butaritari',
#  'ahipara',
#  'pisco',
#  'san javier',
#  'kamaishi',
#  'mirpur sakro',
#  'luena',
#  'luang prabang',
#  'carnarvon',
#  'ribeirao',
#  'gewane',
#  'hofn',
#  'kodiak',
#  'illoqqortoormiut',
#  'saint george',
#  'taolanaro',
#  'oussouye',
#  'mogadishu',
#  'busselton',
#  'vanimo',
#  'upernavik',
#  'inverell',
#  'aklavik',
#  'malartic',
#  'thai binh',
#  'mahebourg',
#  'pechenga',
#  'ilulissat',
#  'fengxian',
#  'saint-joseph',
#  'henties bay',
#  'bur gabo',
#  'valjala',
#  'chapais',
#  'port alfred',
#  'havre-saint-pierre',
#  'aksu',
#  'belmonte',
#  'tsihombe',
#  'tarudant',
#  'luderitz',
#  'pitimbu',
#  'tamparan',
#  'margate',
#  'cap-chat',
#  'pangobilian',
#  'khatanga',
#  'sijunjung',
#  'gamba',
#  'santo domingo',
#  'sheregesh',
#  'abha',
#  'barrow',
#  'kayanza',
#  'hurricane',
#  'balezino',
#  'birin',
#  'deputatskiy',
#  'khokhlovo',
#  'asfi',
#  'stornoway',
#  'labuhan',
#  'dikson',
#  'geraldton',
#  'kerteh',
#  'hobart',
#  'kyra',
#  'aykhal',
#  'ambodifototra',
#  'nikolskoye',
#  'thompson',
#  'duki',
#  'gizo',
#  'seymchan',
#  'east london',
#  'luoyang',
#  'nhulunbuy',
#  'bengkulu',
#  'castro',
#  'bilibino',
#  'westport',
#  'kenai',
#  'hilo',
#  'zyryanka',
#  'mehran',
#  'tumannyy',
#  'zhezkazgan',
#  'halifax',
#  'ancud',
#  'cockburn town',
#  'tarsus',
#  'barentsburg',
#  'egvekinot',
#  'hithadhoo',
#  'bredasdorp',
#  'norman wells',
#  'haibowan',
#  'benguela',
#  'rabo de peixe',
#  'lagoa',
#  'jamestown',
#  'tashtagol',
#  'broken hill',
#  'kruisfontein',
#  'ostrovnoy',
#  'huesca',
#  'bilma',
#  'borborema',
#  'aflu',
#  'goundam',
#  'palmer',
#  'kupang',
#  'rota',
#  'ponta do sol',
#  'roma',
#  'liverpool',
#  'ayan',
#  'pathein',
#  'katobu',
#  'ocean city',
#  'yulara',
#  'camacari',
#  'baculin',
#  'homer',
#  'bathsheba',
#  'codrington',
#  'port blair',
#  'grand centre',
#  'avera',
#  'kumano',
#  'petauke',
#  'nanortalik',
#  'neath',
#  'rodrigues alves',
#  'gunjur',
#  'vila franca do campo',
#  'chagda',
#  'sanski most',
#  'parkes',
#  'tilichiki',
#  'dalvik',
#  'svetlaya',
#  'atuona',
#  'hay river',
#  'jalu',
#  'buchanan',
#  'wanning',
#  'pacific grove',
#  'kurmanayevka',
#  'esperance',
#  'kuche',
#  'kedrovyy',
#  'khomeynishahr',
#  'saint andrews',
#  'college',
#  'khash',
#  'saint augustine',
#  'abashiri',
#  'changji',
#  'batagay-alyta',
#  'vaitupu',
#  'oktyabrskoye',
#  'fort wellington',
#  'noshiro',
#  'hohhot',
#  'byron bay',
#  'sola',
#  'martinsville',
#  'leningradskiy',
#  'kamenka',
#  'san quintin',
#  'vila velha',
#  'labytnangi',
#  'floro',
#  'beyneu',
#  'lazaro cardenas',
#  'tshikapa',
#  'kiruna',
#  'bodh gaya',
#  'orotukan',
#  'chato',
#  'faanui',
#  'nelson bay',
#  'khatassy',
#  'arraial do cabo',
#  'yakeshi',
#  'parauna',
#  'ormara',
#  'palembang',
#  'amga',
#  'mantua',
#  'cherskiy',
#  'lima',
#  'paamiut',
#  'tuatapere',
#  'hami',
#  'kendari',
#  'mys shmidta',
#  'belgrade',
#  'cabo san lucas',
#  'bairiki',
#  'qaanaaq',
#  'souillac',
#  'birjand',
#  'komsomolskiy',
#  'lata',
#  'katsuura',
#  'biak',
#  'mehamn',
#  'satitoa',
#  'praia da vitoria',
#  'kaeo',
#  'pyapon',
#  'karaul',
#  'georgetown',
#  'erenhot',
#  'pedasi',
#  'mizdah',
#  'ust-kuyga',
#  'walvis bay',
#  'balakhta',
#  'lusambo',
#  'asosa',
#  'portland',
#  'touros',
#  'longyearbyen',
#  'urulga',
#  'chortomlyk',
#  'bandundu',
#  'pevek',
#  'kinshasa',
#  'fuerte olimpo',
#  'wahiawa',
#  'shimoda',
#  'saskylakh',
#  'kongolo',
#  'mananara',
#  'jadu',
#  'yekaterinovka',
#  'petropavlovsk-kamchatskiy',
#  'kavieng',
#  'hvolsvollur',
#  'flin flon',
#  'wicklow',
#  'port augusta',
#  'chern',
#  'marion',
#  'myitkyina',
#  'ruatoria',
#  'caxito',
#  'qaqortoq',
#  'yellowknife',
#  'miandrivazo',
#  'cabedelo',
#  'hibbing',
#  'attawapiskat',
#  'salaga',
#  'slavonski brod',
#  'itarema',
#  'ciudad bolivar',
#  'emba',
#  'bukid',
#  'mirnyy',
#  'churapcha',
#  'ishigaki',
#  'karasjok',
#  'korla',
#  'asau',
#  'damara',
#  'zyryanovsk',
#  'dorchester',
#  'adrar',
#  'hamilton',
#  'meulaboh',
#  'kawalu',
#  'creston',
#  'ereymentau',
#  'burica',
#  'solnechnyy',
#  'togul',
#  'haapu',
#  'roura',
#  'armacao dos buzios',
#  'hobyo',
#  'huttwil',
#  'saldanha',
#  'hualmay',
#  'bajo baudo',
#  'jiayuguan',
#  'mahanoro',
#  'mawlaik',
#  'constitucion',
#  'sidi ali',
#  'northam',
#  'chernyakhovsk',
#  'guerrero negro',
#  'axim',
#  'esna',
#  'san carlos',
#  'cidreira',
#  'nanlong',
#  'amderma',
#  'maceio',
#  'bonavista',
#  'abnub',
#  'jacqueville',
#  'hun',
#  'lappeenranta',
#  'zolotinka',
#  'milkovo',
#  'fortuna',
#  'olutanga',
#  'novopskov',
#  'saint-francois',
#  'dwarka',
#  'lakinsk',
#  'yartsevo',
#  'jambi',
#  'obidos',
#  'palauig',
#  'torbay',
#  'riyadh',
#  'gouyave',
#  'shchelyayur',
#  'siavonga',
#  'sovetskiy',
#  'dimbokro',
#  'berdigestyakh',
#  'lekoni',
#  'kilindoni',
#  'mayo',
#  'anloga',
#  'yacopi',
#  'saleaula',
#  'codo',
#  'esso',
#  'bolshevik',
#  'kpandu',
#  'tiksi',
#  'sungaipenuh',
#  'nabire',
#  'samfya',
#  'letlhakane',
#  'hingatungan',
#  'sorkjosen',
#  'tongling',
#  'harper',
#  'fuerte',
#  'brigantine',
#  'vardo',
#  'batagay',
#  'barcelos',
#  'gainsborough',
#  'saint-paul',
#  'camacha',
#  'klaksvik',
#  'ewa beach',
#  'tangier',
#  'boddam',
#  'okhotsk',
#  'pingliang',
#  'alyangula',
#  'ures',
#  'kiunga',
#  'nemuro',
#  'comodoro rivadavia',
#  'nouadhibou',
#  'huarmey',
#  'sakakah',
#  'sanmenxia',
#  'los llanos de aridane',
#  'lixourion',
#  'dhidhdhoo',
#  'kormilovka',
#  'chapada dos guimaraes',
#  'bangui',
#  'provideniya',
#  'chara',
#  'grindavik',
#  'sonoita',
#  'manokwari',
#  'arlit',
#  'marcona',
#  'barberino di mugello',
#  'imeni poliny osipenko',
#  'namibe',
#  'rafai',
#  'beringovskiy',
#  'novyy urengoy',
#  'san juan',
#  'bandarbeyla',
#  'coalcoman',
#  'amos',
#  'sur',
#  'rawson',
#  'muros',
#  'port hardy',
#  'knysna',
#  'baruun-urt',
#  'quatre cocos',
#  'den helder',
#  'port angeles',
#  'severnyy',
#  'benghazi',
#  'goderich',
#  'kalmunai',
#  'diamantino',
#  'ombessa',
#  'iqaluit',
#  'azimur',
#  'hasaki',
#  'redlands',
#  'lavrentiya',
#  'dongning',
#  'leiyang',
#  'qasigiannguit',
#  'tokmak',
#  'brus laguna',
#  'altay',
#  'xadani',
#  'tsukuba',
#  'lompoc',
#  'chabahar',
#  'susangerd',
#  'ratnagiri',
#  'auki',
#  'bolshoy uluy',
#  'abu dhabi',
#  'elesbao veloso',
#  'dunedin',
#  'san patricio',
#  'vuktyl',
#  'luba',
#  'shirokiy',
#  'kande',
#  'mandalgovi',
#  'necochea',
#  'mezen',
#  'poquoson',
#  'pokhara',
#  'buala',
#  'binga',
#  'ayagoz',
#  'stoughton',
#  'kansanshi',
#  'labuan',
#  'bereda',
#  'abbeville',
#  'port macquarie',
#  'srivardhan',
#  'jujuy',
#  'kouango',
#  'alihe',
#  'segezha',
#  'kargasok',
#  'jaque',
#  'coahuayana',
#  'seoul',
#  'redding',
#  'elmira',
#  'cheyenne',
#  'galle',
#  'pouebo',
#  'skarnes',
#  'inuvik',
#  'kibre mengist',
#  'sao joao da barra',
#  'townsville',
#  'ourem',
#  'morant bay',
#  'mildura',
#  'adeje',
#  'bubaque',
#  'southampton',
#  'zhigansk',
#  'canutama',
#  'udaipura',
#  'mercedes',
#  'svarstad',
#  'kahului',
#  'tecpan',
#  'bolungarvik',
#  'guozhen',
#  'nguiu',
#  'takoradi',
#  'fare',
#  'linjiang',
#  'flinders',
#  'pringsewu',
#  'noumea',
#  'bambous virieux',
#  'marsh harbour',
#  'guajara-mirim',
#  'rincon',
#  'pangnirtung',
#  'sorvag',
#  'karratha',
#  'udachnyy',
#  'karachi',
#  'waddan',
#  'la ronge',
#  'billings',
#  'iquitos',
#  'minapasuk',
#  'bambari',
#  'fort saint john',
#  'guadalajara',
#  'evensk',
#  'shenjiamen',
#  'liaozhong',
#  'mastic beach',
#  'matagami',
#  'methoni',
#  'hervey bay',
#  'ermelo',
#  'nantucket',
#  'mayumba',
#  'olafsvik',
#  'onega',
#  'fukue',
#  'malazgirt',
#  'jumla',
#  'sampit',
#  'pacifica',
#  'santa cruz',
#  'san cristobal',
#  'lujiang',
#  'scarborough',
#  'palabuhanratu',
#  'bokhan',
#  'amahai',
#  'kununurra',
#  'gimli',
#  'oranjemund',
#  'puerto leguizamo',
#  'japura',
#  'skjervoy',
#  'nadym',
#  'barawe',
#  'laurel',
#  'antofagasta',
#  'shimanovsk',
#  'inhambane',
#  'turbat',
#  'ho',
#  'suntar',
#  'fairbanks',
#  'talnakh',
#  'ingleside',
#  'znamenskoye',
#  'hondo',
#  'sakaiminato',
#  'kishi',
#  'laguna',
#  'guabito',
#  'marsa matruh',
#  'havoysund',
#  'utuado',
#  'rio gallegos',
#  'alta floresta',
#  'katherine',
#  'sobolevo',
#  'tual',
#  'timbiqui',
#  'yarensk',
#  'yuncheng',
#  'road town',
#  'kenora',
#  'kaitangata']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creating an empty dataframe to store weather data in
weather_df = pd.DataFrame({"City": [],
                           "Lat": [],
                           "Lon": [],
             "Temperature (F)": [],
             "Humidity (%)": [],
             "Cloudiness (%)": [],
             "Wind Speed (mph)": []})

# %%
#loop through each city generated
for city in cities:
    #create a url for the city 
    search_url = f"http://api.openweathermap.org/data/2.5/weather?q={city.replace(' ', '+')}&appid={weather_api_key}&units=imperial"
    #pull a response using the API
    response = requests.get(search_url).json()
    #add weather data if available if not add None and then print the city name and current temp
    try:
        weather_df = weather_df.append({"City": response['name'],
                                        "Lat": response['coord']['lat'],
                                        "Lon": response['coord']['lon'],
                      "Temperature (F)": response['main']['temp'],
                      "Humidity (%)": response['main']['humidity'], 
                      "Cloudiness (%)": response['clouds']['all'],
                      "Wind Speed (mph)": response['wind']['speed']}, ignore_index = True)
        print(f'''
    In {response['name']} (Num: {response['id']}) it is currently {response['main']['temp']} Fahrenheit.
    -----------------------------------''')
    except:
        weather_df = weather_df.append({"City": city,
                                        "Lat": None,
                                        "Lon": None,
                      "Temperature (F)": None,
                      "Humidity (%)": None, 
                      "Cloudiness (%)": None,
                      "Wind Speed (mph)": None}, ignore_index = True)
        print(f'''
    {city} was not found.
    -----------------------------------''')
# Out:
#     In Rikitea (Num: 4030556) it is currently 75.2 Fahrenheit.
#     -----------------------------------
#
#     In Albany (Num: 5106841) it is currently 48.15 Fahrenheit.
#     -----------------------------------
#
#     In Lebu (Num: 3883457) it is currently 52.29 Fahrenheit.
#     -----------------------------------
#
#     In Bethel (Num: 5282297) it is currently 52.95 Fahrenheit.
#     -----------------------------------
#
#     In Manturovo (Num: 529505) it is currently 64.89 Fahrenheit.
#     -----------------------------------
#
#     In Punta Arenas (Num: 3874787) it is currently 44.29 Fahrenheit.
#     -----------------------------------
#
#     bacuit was not found.
#     -----------------------------------
#
#     In Tura (Num: 1254046) it is currently 84.76 Fahrenheit.
#     -----------------------------------
#
#     In Narsaq (Num: 3421719) it is currently 39.2 Fahrenheit.
#     -----------------------------------
#
#     In Chokurdakh (Num: 2126123) it is currently 30.06 Fahrenheit.
#     -----------------------------------
#
#     In Bluff (Num: 2206939) it is currently 46.99 Fahrenheit.
#     -----------------------------------
#
#     sentyabrskiy was not found.
#     -----------------------------------
#
#     In Tiarei (Num: 4033356) it is currently 80.29 Fahrenheit.
#     -----------------------------------
#
#     jiddah was not found.
#     -----------------------------------
#
#     In Ushuaia (Num: 3833367) it is currently 48.2 Fahrenheit.
#     -----------------------------------
#
#     In Cape Town (Num: 3369157) it is currently 62.44 Fahrenheit.
#     -----------------------------------
#
#     In Puerto Ayora (Num: 3652764) it is currently 75.99 Fahrenheit.
#     -----------------------------------
#
#     In Lorengau (Num: 2092164) it is currently 84.74 Fahrenheit.
#     -----------------------------------
#
#     grand river south east was not found.
#     -----------------------------------
#
#     In Władysławowo (Num: 3081752) it is currently 51.39 Fahrenheit.
#     -----------------------------------
#
#     In Jalpatagua (Num: 3595232) it is currently 73.29 Fahrenheit.
#     -----------------------------------
#
#     In Tuktoyaktuk (Num: 6170031) it is currently 33.8 Fahrenheit.
#     -----------------------------------
#
#     In Hokitika (Num: 2206894) it is currently 53.65 Fahrenheit.
#     -----------------------------------
#
#     In Hermanus (Num: 3366880) it is currently 63 Fahrenheit.
#     -----------------------------------
#
#     In Chui (Num: 3443061) it is currently 49.35 Fahrenheit.
#     -----------------------------------
#
#     In Ulladulla (Num: 2145554) it is currently 57.22 Fahrenheit.
#     -----------------------------------
#
#     In Alugan (Num: 1731248) it is currently 83.03 Fahrenheit.
#     -----------------------------------
#
#     In Kavaratti (Num: 1267390) it is currently 82.62 Fahrenheit.
#     -----------------------------------
#
#     In Kieta (Num: 2094027) it is currently 85.06 Fahrenheit.
#     -----------------------------------
#
#     In Horsham (Num: 2646557) it is currently 47.21 Fahrenheit.
#     -----------------------------------
#
#     In Vaini (Num: 4032243) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Coria (Num: 2519234) it is currently 51.01 Fahrenheit.
#     -----------------------------------
#
#     In Mount Gambier (Num: 2156643) it is currently 53.6 Fahrenheit.
#     -----------------------------------
#
#     In Morondava (Num: 1058381) it is currently 75.51 Fahrenheit.
#     -----------------------------------
#
#     In Airai (Num: 1651810) it is currently 71.73 Fahrenheit.
#     -----------------------------------
#
#     In Sydney (Num: 2147714) it is currently 61.12 Fahrenheit.
#     -----------------------------------
#
#     In Dudinka (Num: 1507116) it is currently 21.97 Fahrenheit.
#     -----------------------------------
#
#     In Saint-Philippe (Num: 935215) it is currently 78.1 Fahrenheit.
#     -----------------------------------
#
#     In Sioux Lookout (Num: 6148373) it is currently 51.8 Fahrenheit.
#     -----------------------------------
#
#     In Port Elizabeth (Num: 964420) it is currently 62.6 Fahrenheit.
#     -----------------------------------
#
#     In Ribeira Grande (Num: 3372707) it is currently 64.98 Fahrenheit.
#     -----------------------------------
#
#     In Sitka (Num: 5557293) it is currently 48.2 Fahrenheit.
#     -----------------------------------
#
#     In Arrondissement de Vesoul (Num: 2969561) it is currently 47.44 Fahrenheit.
#     -----------------------------------
#
#     In Rock Sound (Num: 3571592) it is currently 78.03 Fahrenheit.
#     -----------------------------------
#
#     In Avarua (Num: 4035715) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Nome (Num: 5870133) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Gweta (Num: 933734) it is currently 59.63 Fahrenheit.
#     -----------------------------------
#
#     belushya guba was not found.
#     -----------------------------------
#
#     In Hong Kong (Num: 1819729) it is currently 83.7 Fahrenheit.
#     -----------------------------------
#
#     In Severo-Kuril'sk (Num: 2121385) it is currently 42.01 Fahrenheit.
#     -----------------------------------
#
#     In Mataura (Num: 6201424) it is currently 46.99 Fahrenheit.
#     -----------------------------------
#
#     In Sibu (Num: 1735902) it is currently 89.24 Fahrenheit.
#     -----------------------------------
#
#     In Zheleznodorozhnyy (Num: 463355) it is currently 60.17 Fahrenheit.
#     -----------------------------------
#
#     In Tasiilaq (Num: 3424607) it is currently 23 Fahrenheit.
#     -----------------------------------
#
#     In Acarí (Num: 3948613) it is currently 68.59 Fahrenheit.
#     -----------------------------------
#
#     inderborskiy was not found.
#     -----------------------------------
#
#     In Agadez (Num: 2448083) it is currently 84.61 Fahrenheit.
#     -----------------------------------
#
#     nizhneyansk was not found.
#     -----------------------------------
#
#     umzimvubu was not found.
#     -----------------------------------
#
#     In Tessalit (Num: 2449893) it is currently 87.78 Fahrenheit.
#     -----------------------------------
#
#     In Dingle (Num: 1714733) it is currently 90.5 Fahrenheit.
#     -----------------------------------
#
#     In Mar del Plata (Num: 3430863) it is currently 51.17 Fahrenheit.
#     -----------------------------------
#
#     In Merauke (Num: 2082539) it is currently 83.89 Fahrenheit.
#     -----------------------------------
#
#     In Padang (Num: 1633419) it is currently 87.8 Fahrenheit.
#     -----------------------------------
#
#     In Kapaa (Num: 5848280) it is currently 72.95 Fahrenheit.
#     -----------------------------------
#
#     In Progreso (Num: 3521108) it is currently 75.2 Fahrenheit.
#     -----------------------------------
#
#     In Ambilobe (Num: 1082243) it is currently 78.6 Fahrenheit.
#     -----------------------------------
#
#     In São Filipe (Num: 3374210) it is currently 74.91 Fahrenheit.
#     -----------------------------------
#
#     In Machico (Num: 2266895) it is currently 69.8 Fahrenheit.
#     -----------------------------------
#
#     In Abu Samrah (Num: 172515) it is currently 70.21 Fahrenheit.
#     -----------------------------------
#
#     In New Norfolk (Num: 2155415) it is currently 48.87 Fahrenheit.
#     -----------------------------------
#
#     In Bluffton (Num: 4571722) it is currently 59.74 Fahrenheit.
#     -----------------------------------
#
#     In Butaritari (Num: 2110227) it is currently 83.95 Fahrenheit.
#     -----------------------------------
#
#     In Ahipara (Num: 2194098) it is currently 63.28 Fahrenheit.
#     -----------------------------------
#
#     In Pisco (Num: 3932145) it is currently 63.79 Fahrenheit.
#     -----------------------------------
#
#     In San Javier (Num: 2511366) it is currently 59.22 Fahrenheit.
#     -----------------------------------
#
#     In Kamaishi (Num: 2112444) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Mirpur Sakro (Num: 1170290) it is currently 89.6 Fahrenheit.
#     -----------------------------------
#
#     In Luena (Num: 3347719) it is currently 52.23 Fahrenheit.
#     -----------------------------------
#
#     In Luang Prabang (Num: 1655559) it is currently 91.4 Fahrenheit.
#     -----------------------------------
#
#     In Carnarvon (Num: 2074865) it is currently 84.2 Fahrenheit.
#     -----------------------------------
#
#     In Ribeirão (Num: 3390326) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Gewanē (Num: 336745) it is currently 87.76 Fahrenheit.
#     -----------------------------------
#
#     In Hofn (Num: 2630299) it is currently 37.15 Fahrenheit.
#     -----------------------------------
#
#     In Saint Paul Harbor (Num: 5866583) it is currently 42.8 Fahrenheit.
#     -----------------------------------
#
#     illoqqortoormiut was not found.
#     -----------------------------------
#
#     In Saint George (Num: 5546220) it is currently 77.4 Fahrenheit.
#     -----------------------------------
#
#     taolanaro was not found.
#     -----------------------------------
#
#     In Oussouye (Num: 2246901) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Mogadishu (Num: 53654) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Busselton (Num: 2075265) it is currently 67.8 Fahrenheit.
#     -----------------------------------
#
#     In Vanimo (Num: 2084442) it is currently 86.34 Fahrenheit.
#     -----------------------------------
#
#     In Upernavik (Num: 3418910) it is currently 23.83 Fahrenheit.
#     -----------------------------------
#
#     In Inverell (Num: 2162662) it is currently 59.85 Fahrenheit.
#     -----------------------------------
#
#     In Aklavik (Num: 5882953) it is currently 46.4 Fahrenheit.
#     -----------------------------------
#
#     In Malartic (Num: 6064704) it is currently 54.09 Fahrenheit.
#     -----------------------------------
#
#     In Thai Binh (Num: 1566346) it is currently 86 Fahrenheit.
#     -----------------------------------
#
#     In Mahébourg (Num: 934322) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Pechenga (Num: 511865) it is currently 32 Fahrenheit.
#     -----------------------------------
#
#     In Ilulissat (Num: 3423146) it is currently 28.4 Fahrenheit.
#     -----------------------------------
#
#     In Fengxian (Num: 1811200) it is currently 76.41 Fahrenheit.
#     -----------------------------------
#
#     In Saint-Joseph (Num: 6690296) it is currently 77.88 Fahrenheit.
#     -----------------------------------
#
#     In Henties Bay (Num: 3356832) it is currently 64.02 Fahrenheit.
#     -----------------------------------
#
#     bur gabo was not found.
#     -----------------------------------
#
#     valjala was not found.
#     -----------------------------------
#
#     In Chapais (Num: 5919850) it is currently 50 Fahrenheit.
#     -----------------------------------
#
#     In Port Alfred (Num: 964432) it is currently 62.85 Fahrenheit.
#     -----------------------------------
#
#     In Havre-St-Pierre (Num: 5972291) it is currently 46.4 Fahrenheit.
#     -----------------------------------
#
#     In Aksu (Num: 1529660) it is currently 57.13 Fahrenheit.
#     -----------------------------------
#
#     In Belmonte (Num: 3470137) it is currently 69.8 Fahrenheit.
#     -----------------------------------
#
#     tsihombe was not found.
#     -----------------------------------
#
#     tarudant was not found.
#     -----------------------------------
#
#     In Lüderitz (Num: 3355672) it is currently 61.97 Fahrenheit.
#     -----------------------------------
#
#     In Pitimbu (Num: 3391889) it is currently 71.6 Fahrenheit.
#     -----------------------------------
#
#     In Tamparan (Num: 1683425) it is currently 81.23 Fahrenheit.
#     -----------------------------------
#
#     In Margate (Num: 2643044) it is currently 48.13 Fahrenheit.
#     -----------------------------------
#
#     In Cap-Chat (Num: 5915359) it is currently 39.2 Fahrenheit.
#     -----------------------------------
#
#     In Pañgobilian (Num: 1695250) it is currently 84.88 Fahrenheit.
#     -----------------------------------
#
#     In Khatanga (Num: 2022572) it is currently 19.9 Fahrenheit.
#     -----------------------------------
#
#     In Sijunjung (Num: 1627185) it is currently 86.83 Fahrenheit.
#     -----------------------------------
#
#     In Gamba (Num: 2400547) it is currently 76.68 Fahrenheit.
#     -----------------------------------
#
#     In Santo Domingo (Num: 3492908) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Sheregesh (Num: 1492252) it is currently 59.81 Fahrenheit.
#     -----------------------------------
#
#     In Abhā (Num: 110690) it is currently 66.2 Fahrenheit.
#     -----------------------------------
#
#     In Barrow (Num: 5880054) it is currently 23 Fahrenheit.
#     -----------------------------------
#
#     In Kayanza Province (Num: 430951) it is currently 69.8 Fahrenheit.
#     -----------------------------------
#
#     In Hurricane (Num: 5540831) it is currently 77.54 Fahrenheit.
#     -----------------------------------
#
#     In Balezino (Num: 579432) it is currently 71.67 Fahrenheit.
#     -----------------------------------
#
#     In Birin (Num: 1283334) it is currently 72.23 Fahrenheit.
#     -----------------------------------
#
#     In Deputatsky (Num: 2028164) it is currently 29.28 Fahrenheit.
#     -----------------------------------
#
#     In Khokhlovo (Num: 549854) it is currently 55.4 Fahrenheit.
#     -----------------------------------
#
#     In Safi (Num: 2537881) it is currently 62.82 Fahrenheit.
#     -----------------------------------
#
#     In Stornoway (Num: 2636790) it is currently 45.82 Fahrenheit.
#     -----------------------------------
#
#     In Labuhan (Num: 8079926) it is currently 87.62 Fahrenheit.
#     -----------------------------------
#
#     In Dikson (Num: 1507390) it is currently 23.76 Fahrenheit.
#     -----------------------------------
#
#     In Geraldton (Num: 2070998) it is currently 86 Fahrenheit.
#     -----------------------------------
#
#     kerteh was not found.
#     -----------------------------------
#
#     In Hobart (Num: 2163355) it is currently 50.99 Fahrenheit.
#     -----------------------------------
#
#     In Kyra (Num: 2021041) it is currently 60.75 Fahrenheit.
#     -----------------------------------
#
#     In Aykhal (Num: 2027296) it is currently 34.65 Fahrenheit.
#     -----------------------------------
#
#     ambodifototra was not found.
#     -----------------------------------
#
#     In Nikolskoye (Num: 546105) it is currently 61.29 Fahrenheit.
#     -----------------------------------
#
#     In Thompson (Num: 6165406) it is currently 26.6 Fahrenheit.
#     -----------------------------------
#
#     In Duki (Num: 1179515) it is currently 84.42 Fahrenheit.
#     -----------------------------------
#
#     In Gizo Government Station (Num: 2108857) it is currently 85.33 Fahrenheit.
#     -----------------------------------
#
#     In Seymchan (Num: 2121373) it is currently 38.26 Fahrenheit.
#     -----------------------------------
#
#     In East London (Num: 1006984) it is currently 62.6 Fahrenheit.
#     -----------------------------------
#
#     In Luoyang (Num: 1801792) it is currently 74.86 Fahrenheit.
#     -----------------------------------
#
#     In Nhulunbuy (Num: 2064735) it is currently 87.8 Fahrenheit.
#     -----------------------------------
#
#     In Bengkulu (Num: 1649150) it is currently 85.32 Fahrenheit.
#     -----------------------------------
#
#     In Castro (Num: 3466704) it is currently 52.7 Fahrenheit.
#     -----------------------------------
#
#     In Bilibino (Num: 2126682) it is currently 32.85 Fahrenheit.
#     -----------------------------------
#
#     In Westport (Num: 4845585) it is currently 53.6 Fahrenheit.
#     -----------------------------------
#
#     In Kenai (Num: 5866063) it is currently 54.68 Fahrenheit.
#     -----------------------------------
#
#     In Hilo (Num: 5855927) it is currently 71.06 Fahrenheit.
#     -----------------------------------
#
#     In Zyryanka (Num: 2119283) it is currently 40.03 Fahrenheit.
#     -----------------------------------
#
#     In Mehrān (Num: 124291) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     tumannyy was not found.
#     -----------------------------------
#
#     In Zhezkazgan (Num: 1516589) it is currently 68.36 Fahrenheit.
#     -----------------------------------
#
#     In Halifax (Num: 6324729) it is currently 41.41 Fahrenheit.
#     -----------------------------------
#
#     In Ancud (Num: 3899695) it is currently 42.98 Fahrenheit.
#     -----------------------------------
#
#     In Cockburn Town (Num: 3576994) it is currently 79 Fahrenheit.
#     -----------------------------------
#     In Tarsus (Num: 299817) it is currently 68.05 Fahrenheit.
#     -----------------------------------
#
#     barentsburg was not found.
#     -----------------------------------
#
#     In Egvekinot (Num: 4031742) it is currently 31.23 Fahrenheit.
#     -----------------------------------
#
#     In Hithadhoo (Num: 1282256) it is currently 81.54 Fahrenheit.
#     -----------------------------------
#
#     In Bredasdorp (Num: 1015776) it is currently 59 Fahrenheit.
#     -----------------------------------
#
#     In Norman Wells (Num: 6089245) it is currently 42.8 Fahrenheit.
#     -----------------------------------
#
#     haibowan was not found.
#     -----------------------------------
#
#     In Benguela (Num: 3351663) it is currently 76.08 Fahrenheit.
#     -----------------------------------
#
#     In Rabo de Peixe (Num: 3372745) it is currently 64.4 Fahrenheit.
#     -----------------------------------
#
#     In Lagoa (Num: 3372964) it is currently 63.75 Fahrenheit.
#     -----------------------------------
#
#     In Jamestown (Num: 5122534) it is currently 43.7 Fahrenheit.
#     -----------------------------------
#
#     In Tashtagol (Num: 1490042) it is currently 61.52 Fahrenheit.
#     -----------------------------------
#
#     In Broken Hill (Num: 2173911) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Kruisfontein (Num: 986717) it is currently 55.99 Fahrenheit.
#     -----------------------------------
#
#     In Ostrovnoy (Num: 556268) it is currently 31.46 Fahrenheit.
#     -----------------------------------
#
#     In Huesca (Num: 3120514) it is currently 51.94 Fahrenheit.
#     -----------------------------------
#
#     In Bilma (Num: 2446796) it is currently 86.31 Fahrenheit.
#     -----------------------------------
#
#     In Borborema (Num: 3469173) it is currently 59.94 Fahrenheit.
#     -----------------------------------
#
#     aflu was not found.
#     -----------------------------------
#
#     In Goundam (Num: 2456917) it is currently 87.26 Fahrenheit.
#     -----------------------------------
#
#     In Palmer (Num: 4946620) it is currently 47.07 Fahrenheit.
#     -----------------------------------
#
#     In Kupang (Num: 2057087) it is currently 87.8 Fahrenheit.
#     -----------------------------------
#
#     In Rota (Num: 2511700) it is currently 58.08 Fahrenheit.
#     -----------------------------------
#
#     In Ponta do Sol (Num: 2264557) it is currently 64.78 Fahrenheit.
#     -----------------------------------
#
#     In Rome (Num: 5134295) it is currently 43.29 Fahrenheit.
#     -----------------------------------
#
#     In Liverpool (Num: 2644210) it is currently 48.42 Fahrenheit.
#     -----------------------------------
#
#     In Ayan (Num: 2027316) it is currently 32.4 Fahrenheit.
#     -----------------------------------
#
#     In Pathein (Num: 1328421) it is currently 98.53 Fahrenheit.
#     -----------------------------------
#
#     In Katobu (Num: 1640972) it is currently 84.87 Fahrenheit.
#     -----------------------------------
#
#     In Ocean City (Num: 4503351) it is currently 56.12 Fahrenheit.
#     -----------------------------------
#
#     In Yulara (Num: 6355222) it is currently 68 Fahrenheit.
#     -----------------------------------
#
#     In Camaçari (Num: 3468031) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Baculin (Num: 1729469) it is currently 85.41 Fahrenheit.
#     -----------------------------------
#
#     In Homer (Num: 5864145) it is currently 46.17 Fahrenheit.
#     -----------------------------------
#
#     In Bathsheba (Num: 3374083) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Codrington (Num: 2171099) it is currently 53.91 Fahrenheit.
#     -----------------------------------
#
#     In Port Blair (Num: 1259385) it is currently 89.6 Fahrenheit.
#     -----------------------------------
#
#     grand centre was not found.
#     -----------------------------------
#
#     In Avera (Num: 4231997) it is currently 51.53 Fahrenheit.
#     -----------------------------------
#
#     In Kumano (Num: 1862415) it is currently 69.64 Fahrenheit.
#     -----------------------------------
#
#     In Petauke (Num: 899825) it is currently 58.68 Fahrenheit.
#     -----------------------------------
#
#     In Nanortalik (Num: 3421765) it is currently 37.71 Fahrenheit.
#     -----------------------------------
#
#     In Neath (Num: 2641843) it is currently 48.02 Fahrenheit.
#     -----------------------------------
#
#     In Rodrigues Alves (Num: 3665210) it is currently 70.41 Fahrenheit.
#     -----------------------------------
#
#     In Gunjur (Num: 2413419) it is currently 71.6 Fahrenheit.
#     -----------------------------------
#
#     In Vila Franca do Campo (Num: 3372472) it is currently 64.4 Fahrenheit.
#     -----------------------------------
#
#     chagda was not found.
#     -----------------------------------
#
#     In Sanski Most (Num: 3191297) it is currently 51.01 Fahrenheit.
#     -----------------------------------
#
#     In Parkes (Num: 2153778) it is currently 57 Fahrenheit.
#     -----------------------------------
#
#     In Tilichiki (Num: 2120591) it is currently 32.36 Fahrenheit.
#     -----------------------------------
#
#     In Dalvik (Num: 2632287) it is currently 33.8 Fahrenheit.
#     -----------------------------------
#
#     In Svetlaya (Num: 2015852) it is currently 48.16 Fahrenheit.
#     -----------------------------------
#
#     In Atuona (Num: 4020109) it is currently 79.52 Fahrenheit.
#     -----------------------------------
#
#     In Hay River (Num: 5972762) it is currently 34.7 Fahrenheit.
#     -----------------------------------
#
#     In Jalu (Num: 86049) it is currently 75.31 Fahrenheit.
#     -----------------------------------
#
#     In Buchanan (Num: 2278158) it is currently 78.26 Fahrenheit.
#     -----------------------------------
#
#     In Wanning (Num: 1791779) it is currently 89.56 Fahrenheit.
#     -----------------------------------
#
#     In Pacific Grove (Num: 5380437) it is currently 50.88 Fahrenheit.
#     -----------------------------------
#
#     In Kurmanayevka (Num: 538685) it is currently 76.17 Fahrenheit.
#     -----------------------------------
#
#     In Esperance (Num: 2071860) it is currently 64.4 Fahrenheit.
#     -----------------------------------
#
#     kuche was not found.
#     -----------------------------------
#
#     In Kedrovyy (Num: 1538641) it is currently 53.6 Fahrenheit.
#     -----------------------------------
#
#     khomeynishahr was not found.
#     -----------------------------------
#
#     In Saint Andrews (Num: 4593724) it is currently 52.03 Fahrenheit.
#     -----------------------------------
#
#     In College (Num: 5859699) it is currently 56.77 Fahrenheit.
#     -----------------------------------
#
#     In Khāsh (Num: 1160571) it is currently 77.59 Fahrenheit.
#     -----------------------------------
#
#     In Saint Augustine (Num: 4170894) it is currently 67.41 Fahrenheit.
#     -----------------------------------
#
#     In Abashiri (Num: 2130741) it is currently 69.8 Fahrenheit.
#     -----------------------------------
#
#     In Changji (Num: 1529569) it is currently 62.6 Fahrenheit.
#     -----------------------------------
#
#     In Batagay-Alyta (Num: 2027042) it is currently 46.87 Fahrenheit.
#     -----------------------------------
#
#     vaitupu was not found.
#     -----------------------------------
#
#     In Oktyabr'skoye (Num: 515805) it is currently 71.29 Fahrenheit.
#     -----------------------------------
#
#     In Catherinas Lust (Num: 3378690) it is currently 76.28 Fahrenheit.
#     -----------------------------------
#
#     In Noshiro (Num: 2128867) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Hohhot (Num: 2036892) it is currently 55.4 Fahrenheit.
#     -----------------------------------
#
#     In Byron Bay (Num: 2172880) it is currently 71.78 Fahrenheit.
#     -----------------------------------
#
#     In Sola (Num: 2134814) it is currently 81.9 Fahrenheit.
#     -----------------------------------
#
#     In Martinsville (Num: 4771808) it is currently 44.71 Fahrenheit.
#     -----------------------------------
#
#     In Leningradskiy (Num: 2123814) it is currently 32.22 Fahrenheit.
#     -----------------------------------
#
#     In Kamenka (Num: 553766) it is currently 66.07 Fahrenheit.
#     -----------------------------------
#
#     In San Quintín (Num: 3984997) it is currently 48.99 Fahrenheit.
#     -----------------------------------
#     In Vila Velha (Num: 3445026) it is currently 64.71 Fahrenheit.
#     -----------------------------------
#
#     In Labytnangi (Num: 1500933) it is currently 34.12 Fahrenheit.
#     -----------------------------------
#
#     In Florø (Num: 3156980) it is currently 53.6 Fahrenheit.
#     -----------------------------------
#
#     In Beyneu (Num: 610298) it is currently 83.79 Fahrenheit.
#     -----------------------------------
#
#     In Lázaro Cárdenas (Num: 4026082) it is currently 80.62 Fahrenheit.
#     -----------------------------------
#
#     In Tshikapa (Num: 204953) it is currently 67.62 Fahrenheit.
#     -----------------------------------
#
#     In Kiruna (Num: 605155) it is currently 32 Fahrenheit.
#     -----------------------------------
#
#     In Bodh Gaya (Num: 1275389) it is currently 93.2 Fahrenheit.
#     -----------------------------------
#
#     In Orotukan (Num: 2122414) it is currently 35.64 Fahrenheit.
#     -----------------------------------
#
#     In Chato (Num: 160552) it is currently 65.66 Fahrenheit.
#     -----------------------------------
#
#     In Faanui (Num: 4034551) it is currently 82.49 Fahrenheit.
#     -----------------------------------
#
#     In Nelson Bay (Num: 2155562) it is currently 63.7 Fahrenheit.
#     -----------------------------------
#
#     In Khatassy (Num: 2022564) it is currently 62.6 Fahrenheit.
#     -----------------------------------
#
#     In Arraial do Cabo (Num: 3471451) it is currently 69.01 Fahrenheit.
#     -----------------------------------
#
#     In Yakeshi (Num: 2033536) it is currently 55.65 Fahrenheit.
#     -----------------------------------
#
#     In Paraúna (Num: 3455020) it is currently 64.99 Fahrenheit.
#     -----------------------------------
#
#     In Ormara (Num: 1168700) it is currently 84.83 Fahrenheit.
#     -----------------------------------
#
#     In Palembang (Num: 1633070) it is currently 89.6 Fahrenheit.
#     -----------------------------------
#
#     In Amga (Num: 2027786) it is currently 58.82 Fahrenheit.
#     -----------------------------------
#
#     In Province of Mantua (Num: 3174050) it is currently 51.01 Fahrenheit.
#     -----------------------------------
#
#     In Cherskiy (Num: 2126199) it is currently 34.77 Fahrenheit.
#     -----------------------------------
#
#     In Lima (Num: 3936456) it is currently 63.46 Fahrenheit.
#     -----------------------------------
#
#     In Paamiut (Num: 3421193) it is currently 36.93 Fahrenheit.
#     -----------------------------------
#
#     In Tuatapere (Num: 2180815) it is currently 46.99 Fahrenheit.
#     -----------------------------------
#
#     In Kumul (Num: 1529484) it is currently 75.54 Fahrenheit.
#     -----------------------------------
#
#     In Kendari (Num: 1640344) it is currently 78.13 Fahrenheit.
#     -----------------------------------
#
#     mys shmidta was not found.
#     -----------------------------------
#
#     In Belgrade (Num: 792680) it is currently 56.3 Fahrenheit.
#     -----------------------------------
#
#     In Cabo San Lucas (Num: 3985710) it is currently 82.36 Fahrenheit.
#     -----------------------------------
#
#     In Bairiki Village (Num: 7601762) it is currently 87.8 Fahrenheit.
#     -----------------------------------
#
#     In Qaanaaq (Num: 3831208) it is currently 26.56 Fahrenheit.
#     -----------------------------------
#
#     In Souillac (Num: 933995) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Birjand (Num: 140463) it is currently 68 Fahrenheit.
#     -----------------------------------
#
#     In Yangi Marg`ilon (Num: 1513491) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Lata (Num: 2738381) it is currently 55.99 Fahrenheit.
#     -----------------------------------
#
#     In Katsuura (Num: 2112309) it is currently 78.44 Fahrenheit.
#     -----------------------------------
#
#     In Biak (Num: 1637001) it is currently 81.37 Fahrenheit.
#     -----------------------------------
#
#     In Mehamn (Num: 778707) it is currently 35.22 Fahrenheit.
#     -----------------------------------
#
#     satitoa was not found.
#     -----------------------------------
#
#     In Praia da Vitória (Num: 3372760) it is currently 65.26 Fahrenheit.
#     -----------------------------------
#
#     In Kaeo (Num: 2189343) it is currently 66.99 Fahrenheit.
#     -----------------------------------
#
#     In Pyapon (Num: 1299237) it is currently 98.1 Fahrenheit.
#     -----------------------------------
#
#     karaul was not found.
#     -----------------------------------
#
#     In George Town (Num: 1735106) it is currently 89.38 Fahrenheit.
#     -----------------------------------
#
#     In Erenhot (Num: 2037485) it is currently 57.96 Fahrenheit.
#     -----------------------------------
#
#     In Pedasí (Num: 3703239) it is currently 72 Fahrenheit.
#     -----------------------------------
#
#     In Mizdah (Num: 2214827) it is currently 70.45 Fahrenheit.
#     -----------------------------------
#
#     In Ust-Kuyga (Num: 2013921) it is currently 38.73 Fahrenheit.
#     -----------------------------------
#
#     In Walvis Bay (Num: 3359638) it is currently 66.2 Fahrenheit.
#     -----------------------------------
#
#     In Balakhta (Num: 1510998) it is currently 55.27 Fahrenheit.
#     -----------------------------------
#
#     In Lusambo (Num: 210379) it is currently 69.42 Fahrenheit.
#     -----------------------------------
#
#     In Āsosa (Num: 343292) it is currently 66.25 Fahrenheit.
#     -----------------------------------
#
#     In Portland (Num: 5746545) it is currently 62.33 Fahrenheit.
#     -----------------------------------
#
#     In Touros (Num: 3386213) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Longyearbyen (Num: 2729907) it is currently 21.2 Fahrenheit.
#     -----------------------------------
#
#     urulga was not found.
#     -----------------------------------
#
#     In Chortomlyk (Num: 710615) it is currently 62.37 Fahrenheit.
#     -----------------------------------
#
#     In Bandundu Province (Num: 2317397) it is currently 71.76 Fahrenheit.
#     -----------------------------------
#
#     In Pevek (Num: 2122090) it is currently 30.69 Fahrenheit.
#     -----------------------------------
#
#     In Kinshasa (Num: 2314302) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Fuerte Olimpo (Num: 3438102) it is currently 64.36 Fahrenheit.
#     -----------------------------------
#
#     In Wahiawā (Num: 5853992) it is currently 73.36 Fahrenheit.
#     -----------------------------------
#
#     In Shimoda (Num: 1852357) it is currently 73.6 Fahrenheit.
#     -----------------------------------
#
#     In Saskylakh (Num: 2017155) it is currently 30.11 Fahrenheit.
#     -----------------------------------
#
#     In Kongolo (Num: 212360) it is currently 71.92 Fahrenheit.
#     -----------------------------------
#
#     In Mananara (Num: 1061412) it is currently 75.97 Fahrenheit.
#     -----------------------------------
#
#     In Jadu (Num: 2216432) it is currently 58.87 Fahrenheit.
#     -----------------------------------
#
#     In Yekaterinovka (Num: 468180) it is currently 68.4 Fahrenheit.
#     -----------------------------------
#
#     In Petropavlovsk-Kamchatskiy (Num: 2122104) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Kavieng (Num: 2094342) it is currently 85.33 Fahrenheit.
#     -----------------------------------
#
#     In Hvolsvollur (Num: 3415720) it is currently 28.99 Fahrenheit.
#     -----------------------------------
#
#     In Flin Flon (Num: 5954718) it is currently 42.37 Fahrenheit.
#     -----------------------------------
#
#     In County Wicklow (Num: 2960935) it is currently 45.01 Fahrenheit.
#     -----------------------------------
#
#     In Port Augusta (Num: 2063056) it is currently 62.17 Fahrenheit.
#     -----------------------------------
#
#     In Chern' (Num: 569116) it is currently 61.81 Fahrenheit.
#     -----------------------------------
#
#     In Marion (Num: 4260977) it is currently 50.47 Fahrenheit.
#     -----------------------------------
#
#     In Myitkyina (Num: 1307741) it is currently 93.92 Fahrenheit.
#     -----------------------------------
#
#     ruatoria was not found.
#     -----------------------------------
#
#     In Caxito (Num: 2242001) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Qaqortoq (Num: 3420846) it is currently 39.2 Fahrenheit.
#     -----------------------------------
#     In Yellowknife (Num: 6185377) it is currently 28.78 Fahrenheit.
#     -----------------------------------
#
#     In Miandrivazo (Num: 1059051) it is currently 76.91 Fahrenheit.
#     -----------------------------------
#
#     In Cabedelo (Num: 3404558) it is currently 71.6 Fahrenheit.
#     -----------------------------------
#
#     In Hibbing (Num: 5030005) it is currently 47.17 Fahrenheit.
#     -----------------------------------
#
#     attawapiskat was not found.
#     -----------------------------------
#
#     In Salaga (Num: 2295684) it is currently 77.67 Fahrenheit.
#     -----------------------------------
#
#     In Slavonski Brod (Num: 3190586) it is currently 53.35 Fahrenheit.
#     -----------------------------------
#
#     In Itarema (Num: 3393692) it is currently 74.17 Fahrenheit.
#     -----------------------------------
#
#     In Ciudad Bolivar (Num: 3645532) it is currently 78.94 Fahrenheit.
#     -----------------------------------
#
#     In Emba (Num: 609924) it is currently 80.38 Fahrenheit.
#     -----------------------------------
#
#     In Bukid (Num: 1722530) it is currently 93.2 Fahrenheit.
#     -----------------------------------
#
#     In Mirny (Num: 2019951) it is currently 61.32 Fahrenheit.
#     -----------------------------------
#
#     In Churapcha (Num: 2025241) it is currently 60.03 Fahrenheit.
#     -----------------------------------
#
#     In Ishigaki (Num: 1861416) it is currently 86 Fahrenheit.
#     -----------------------------------
#
#     In Karasjok (Num: 779350) it is currently 35.6 Fahrenheit.
#     -----------------------------------
#
#     In Korla (Num: 1529376) it is currently 68.36 Fahrenheit.
#     -----------------------------------
#
#     In Asău (Num: 686090) it is currently 59 Fahrenheit.
#     -----------------------------------
#
#     In Damara (Num: 2387435) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Zyryanovsk (Num: 1516438) it is currently 62.62 Fahrenheit.
#     -----------------------------------
#
#     In Dorchester (Num: 4576822) it is currently 52.27 Fahrenheit.
#     -----------------------------------
#
#     In Adrar (Num: 2381972) it is currently 73.58 Fahrenheit.
#     -----------------------------------
#
#     In Hamilton (Num: 4513583) it is currently 48.74 Fahrenheit.
#     -----------------------------------
#
#     In Meulaboh (Num: 1214488) it is currently 85.6 Fahrenheit.
#     -----------------------------------
#
#     In Kawalu (Num: 1640902) it is currently 84.85 Fahrenheit.
#     -----------------------------------
#
#     In Creston (Num: 4853078) it is currently 58.59 Fahrenheit.
#     -----------------------------------
#
#     In Ereymentau (Num: 1524302) it is currently 66.92 Fahrenheit.
#     -----------------------------------
#
#     burica was not found.
#     -----------------------------------
#
#     In Solnechnyy (Num: 2016307) it is currently 48.04 Fahrenheit.
#     -----------------------------------
#
#     In Togul (Num: 1489504) it is currently 64.53 Fahrenheit.
#     -----------------------------------
#
#     haapu was not found.
#     -----------------------------------
#
#     In Roura (Num: 3380450) it is currently 75.04 Fahrenheit.
#     -----------------------------------
#
#     armacao dos buzios was not found.
#     -----------------------------------
#
#     In Hobyo (Num: 57000) it is currently 83.25 Fahrenheit.
#     -----------------------------------
#
#     In Huttwil (Num: 2660281) it is currently 41.34 Fahrenheit.
#     -----------------------------------
#
#     In Saldanha (Num: 3361934) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Hualmay (Num: 3939761) it is currently 63.86 Fahrenheit.
#     -----------------------------------
#
#     bajo baudo was not found.
#     -----------------------------------
#
#     In Jiayuguan City (Num: 1280957) it is currently 64.35 Fahrenheit.
#     -----------------------------------
#
#     In Mahanoro (Num: 1062553) it is currently 73.69 Fahrenheit.
#     -----------------------------------
#
#     In Mawlaik (Num: 1310120) it is currently 101.59 Fahrenheit.
#     -----------------------------------
#
#     In Constitución (Num: 3893726) it is currently 55.29 Fahrenheit.
#     -----------------------------------
#
#     In Sidi Ali (Num: 2487130) it is currently 60.82 Fahrenheit.
#     -----------------------------------
#
#     In Northam (Num: 2641434) it is currently 46.33 Fahrenheit.
#     -----------------------------------
#
#     In Chernyakhovsk (Num: 568595) it is currently 49.89 Fahrenheit.
#     -----------------------------------
#
#     In Guerrero Negro (Num: 4021858) it is currently 59.2 Fahrenheit.
#     -----------------------------------
#
#     In Esim (Num: 2303611) it is currently 79.66 Fahrenheit.
#     -----------------------------------
#
#     In Esna (Num: 355449) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In San Carlos (Num: 3628503) it is currently 74.52 Fahrenheit.
#     -----------------------------------
#
#     In Cidreira (Num: 3466165) it is currently 58.44 Fahrenheit.
#     -----------------------------------
#
#     In Nanlong (Num: 1799908) it is currently 63.95 Fahrenheit.
#     -----------------------------------
#
#     amderma was not found.
#     -----------------------------------
#
#     In Maceió (Num: 3395981) it is currently 71.6 Fahrenheit.
#     -----------------------------------
#
#     In Bonavista (Num: 5905393) it is currently 39.51 Fahrenheit.
#     -----------------------------------
#
#     In Abnūb (Num: 362973) it is currently 68 Fahrenheit.
#     -----------------------------------
#
#     In Jacqueville (Num: 2287778) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Hūn (Num: 2216645) it is currently 73.65 Fahrenheit.
#     -----------------------------------
#
#     In Lappeenranta (Num: 648900) it is currently 57.85 Fahrenheit.
#     -----------------------------------
#
#     zolotinka was not found.
#     -----------------------------------
#
#     In Mil'kovo (Num: 2123278) it is currently 56.41 Fahrenheit.
#     -----------------------------------
#
#     In Fortuna (Num: 5563839) it is currently 48.63 Fahrenheit.
#     -----------------------------------
#
#     In Olutanga (Num: 1697155) it is currently 82.27 Fahrenheit.
#     -----------------------------------
#
#     In Novopskov (Num: 699311) it is currently 65.39 Fahrenheit.
#     -----------------------------------
#
#     In Saint-François (Num: 2980080) it is currently 47.75 Fahrenheit.
#     -----------------------------------
#
#     In Dwārka (Num: 1272140) it is currently 86.27 Fahrenheit.
#     -----------------------------------
#
#     In Lakinsk (Num: 537107) it is currently 62.78 Fahrenheit.
#     -----------------------------------
#
#     In Yartsevo (Num: 468866) it is currently 56.68 Fahrenheit.
#     -----------------------------------
#
#     In Jambi City (Num: 1642858) it is currently 90.81 Fahrenheit.
#     -----------------------------------
#
#     In Óbidos (Num: 3393768) it is currently 73.54 Fahrenheit.
#     -----------------------------------
#
#     In Palauig (Num: 1696188) it is currently 91.67 Fahrenheit.
#     -----------------------------------
#
#     In Torbay (Num: 6167817) it is currently 40.69 Fahrenheit.
#     -----------------------------------
#
#     In Riyadh (Num: 108410) it is currently 90.73 Fahrenheit.
#     -----------------------------------
#
#     In Gouyave (Num: 3580279) it is currently 78.76 Fahrenheit.
#     -----------------------------------
#
#     shchelyayur was not found.
#     -----------------------------------
#
#     In Siavonga (Num: 898188) it is currently 64.22 Fahrenheit.
#     -----------------------------------
#
#     In Sovetskiy (Num: 1491230) it is currently 67.55 Fahrenheit.
#     -----------------------------------
#
#     In Dimbokro (Num: 2289983) it is currently 74.44 Fahrenheit.
#     -----------------------------------
#
#     In Berdigestyakh (Num: 2026861) it is currently 62.08 Fahrenheit.
#     -----------------------------------
#
#     In Lékoni (Num: 2399831) it is currently 73.72 Fahrenheit.
#     -----------------------------------
#
#     In Kilindoni (Num: 157429) it is currently 79.38 Fahrenheit.
#     -----------------------------------
#
#     In Mayo (Num: 4362001) it is currently 54.09 Fahrenheit.
#     -----------------------------------
#
#     In Anloga (Num: 2304548) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#     In Yacopí (Num: 3665813) it is currently 60.62 Fahrenheit.
#     -----------------------------------
#
#     saleaula was not found.
#     -----------------------------------
#
#     In Codó (Num: 3402000) it is currently 72.91 Fahrenheit.
#     -----------------------------------
#
#     In Esso (Num: 2125711) it is currently 38.88 Fahrenheit.
#     -----------------------------------
#
#     In Bolshevik (Num: 625144) it is currently 53.31 Fahrenheit.
#     -----------------------------------
#
#     In Kpandu (Num: 2299233) it is currently 75.58 Fahrenheit.
#     -----------------------------------
#
#     In Tiksi (Num: 2015306) it is currently 35.89 Fahrenheit.
#     -----------------------------------
#
#     In Sungai Penuh (Num: 1625929) it is currently 77.22 Fahrenheit.
#     -----------------------------------
#
#     In Nabire (Num: 1634614) it is currently 87.04 Fahrenheit.
#     -----------------------------------
#
#     In Samfya (Num: 899274) it is currently 59.32 Fahrenheit.
#     -----------------------------------
#
#     In Letlhakane (Num: 933535) it is currently 54.36 Fahrenheit.
#     -----------------------------------
#
#     In Hingatungan (Num: 1711635) it is currently 84.76 Fahrenheit.
#     -----------------------------------
#
#     In Sørkjosen (Num: 777572) it is currently 38.12 Fahrenheit.
#     -----------------------------------
#
#     In Tongling (Num: 1792621) it is currently 86.81 Fahrenheit.
#     -----------------------------------
#
#     In Harper (Num: 2276492) it is currently 78.87 Fahrenheit.
#     -----------------------------------
#
#     In Fuerte (Num: 1713558) it is currently 89.8 Fahrenheit.
#     -----------------------------------
#
#     In Brigantine (Num: 4500920) it is currently 52.57 Fahrenheit.
#     -----------------------------------
#
#     In Vardø (Num: 777019) it is currently 35.1 Fahrenheit.
#     -----------------------------------
#
#     In Batagay (Num: 2027044) it is currently 51.39 Fahrenheit.
#     -----------------------------------
#
#     In Barcelos (Num: 2742416) it is currently 57.29 Fahrenheit.
#     -----------------------------------
#
#     In Gainsborough (Num: 2648945) it is currently 45.91 Fahrenheit.
#     -----------------------------------
#
#     In Saint-Paul (Num: 935221) it is currently 78.17 Fahrenheit.
#     -----------------------------------
#
#     In Camacha (Num: 2270385) it is currently 64.4 Fahrenheit.
#     -----------------------------------
#
#     In Klaksvík (Num: 2618795) it is currently 39.2 Fahrenheit.
#     -----------------------------------
#
#     In ‘Ewa Beach (Num: 5855051) it is currently 77.05 Fahrenheit.
#     -----------------------------------
#
#     In Tangier (Num: 2530335) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Boddam (Num: 2655288) it is currently 42.93 Fahrenheit.
#     -----------------------------------
#
#     In Okhotsk (Num: 2122605) it is currently 34.5 Fahrenheit.
#     -----------------------------------
#
#     In Pingliang (Num: 1798760) it is currently 48.09 Fahrenheit.
#     -----------------------------------
#
#     In Alyangula (Num: 2079582) it is currently 84.2 Fahrenheit.
#     -----------------------------------
#
#     In Ures (Num: 3980782) it is currently 79.41 Fahrenheit.
#     -----------------------------------
#
#     In Kiunga (Num: 2093846) it is currently 85.6 Fahrenheit.
#     -----------------------------------
#
#     In Nemuro (Num: 2128975) it is currently 66.2 Fahrenheit.
#     -----------------------------------
#
#     In Comodoro Rivadavia (Num: 3860443) it is currently 50 Fahrenheit.
#     -----------------------------------
#
#     In Nouadhibou (Num: 2377457) it is currently 66.2 Fahrenheit.
#     -----------------------------------
#
#     In Huarmey (Num: 3939168) it is currently 64.85 Fahrenheit.
#     -----------------------------------
#
#     In Sakakah (Num: 102527) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Sanmenxia (Num: 1796669) it is currently 61.99 Fahrenheit.
#     -----------------------------------
#
#     In Los Llanos de Aridane (Num: 2514651) it is currently 63.21 Fahrenheit.
#     -----------------------------------
#
#     In Lixouri (Num: 258175) it is currently 64.47 Fahrenheit.
#     -----------------------------------
#
#     In Dhidhdhoo (Num: 1337612) it is currently 84.51 Fahrenheit.
#     -----------------------------------
#
#     In Kormilovka (Num: 1502526) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Chapada dos Guimarães (Num: 3466307) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Bangui (Num: 2389853) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Provideniya (Num: 4031574) it is currently 46.08 Fahrenheit.
#     -----------------------------------
#
#     In Chara (Num: 2025630) it is currently 50.43 Fahrenheit.
#     -----------------------------------
#
#     In Grindavik (Num: 3416888) it is currently 35.6 Fahrenheit.
#     -----------------------------------
#
#     In Sonoita (Num: 3982837) it is currently 73.02 Fahrenheit.
#     -----------------------------------
#
#     In Manokwari (Num: 1636308) it is currently 84.11 Fahrenheit.
#     -----------------------------------
#
#     In Arlit (Num: 2447513) it is currently 86.54 Fahrenheit.
#     -----------------------------------
#
#     marcona was not found.
#     -----------------------------------
#
#     In Barberino di Mugello (Num: 3182390) it is currently 48.45 Fahrenheit.
#     -----------------------------------
#
#     In Imeni Poliny Osipenko (Num: 2023584) it is currently 51.73 Fahrenheit.
#     -----------------------------------
#
#     In Mossamedes (Num: 3347019) it is currently 76.64 Fahrenheit.
#     -----------------------------------
#
#     In Rafai (Num: 236524) it is currently 69.62 Fahrenheit.
#     -----------------------------------
#
#     In Beringovskiy (Num: 2126710) it is currently 33.42 Fahrenheit.
#     -----------------------------------
#
#     In Novy Urengoy (Num: 1496511) it is currently 31.24 Fahrenheit.
#     -----------------------------------
#
#     In San Juan (Num: 3837213) it is currently 59.61 Fahrenheit.
#     -----------------------------------
#
#     In Bandarbeyla (Num: 64814) it is currently 90.63 Fahrenheit.
#     -----------------------------------
#
#     coalcoman was not found.
#     -----------------------------------
#
#     In Amos (Num: 5884588) it is currently 53.87 Fahrenheit.
#     -----------------------------------
#
#     In Sur (Num: 286245) it is currently 92.43 Fahrenheit.
#     -----------------------------------
#
#     In Rawson (Num: 3839307) it is currently 53.49 Fahrenheit.
#     -----------------------------------
#
# ...
#
#     In Leiyang (Num: 1804208) it is currently 92.88 Fahrenheit.
#     -----------------------------------
#
#     In Qasigiannguit (Num: 3420768) it is currently 28.4 Fahrenheit.
#     -----------------------------------
#
#     In Tokmak (Num: 691469) it is currently 62.91 Fahrenheit.
#     -----------------------------------
#
#     In Brus Laguna (Num: 3614663) it is currently 74.68 Fahrenheit.
#     -----------------------------------
#
#     In Altay (Num: 1529651) it is currently 64.29 Fahrenheit.
#     -----------------------------------
#
#     xadani was not found.
#     -----------------------------------
#
#     In Tsukuba (Num: 2110683) it is currently 78.15 Fahrenheit.
#     -----------------------------------
#
#     In Lompoc (Num: 5367788) it is currently 50.31 Fahrenheit.
#     -----------------------------------
#
#     In Chabahar (Num: 1161724) it is currently 89.37 Fahrenheit.
#     -----------------------------------
#
#     In Sūsangerd (Num: 137268) it is currently 93.2 Fahrenheit.
#     -----------------------------------
#
#     In Ratnagiri (Num: 1258338) it is currently 94.15 Fahrenheit.
#     -----------------------------------
#
#     In Auki (Num: 2109701) it is currently 84.92 Fahrenheit.
#     -----------------------------------
#
#     bolshoy uluy was not found.
#     -----------------------------------
#
#     In Abu Dhabi (Num: 292968) it is currently 84.43 Fahrenheit.
#     -----------------------------------
#
#     In Elesbão Veloso (Num: 3400920) it is currently 74.57 Fahrenheit.
#     -----------------------------------
#
#     In Dunedin (Num: 2191562) it is currently 52 Fahrenheit.
#     -----------------------------------
#
#     In San Patricio (Num: 4726521) it is currently 75 Fahrenheit.
#     -----------------------------------
#
#     In Vuktyl (Num: 470905) it is currently 62.83 Fahrenheit.
#     -----------------------------------
#
#     In Luba (Num: 2309528) it is currently 73.4 Fahrenheit.
#     -----------------------------------
#
#     In Shirokiy (Num: 2016680) it is currently 56.97 Fahrenheit.
#     -----------------------------------
#
#     In Kandé (Num: 2366168) it is currently 79.34 Fahrenheit.
#     -----------------------------------
#
#     In Mandalgovi (Num: 2030065) it is currently 56.1 Fahrenheit.
#     -----------------------------------
#
#     In Necochea (Num: 3430443) it is currently 53.4 Fahrenheit.
#     -----------------------------------
#
#     In Mezen' (Num: 527321) it is currently 48.6 Fahrenheit.
#     -----------------------------------
#
#     In Poquoson (Num: 4779923) it is currently 51.87 Fahrenheit.
#     -----------------------------------
#
#     In Pokhara (Num: 1282898) it is currently 83.55 Fahrenheit.
#     -----------------------------------
#
#     In Buala (Num: 2109528) it is currently 85.14 Fahrenheit.
#     -----------------------------------
#
#     In Binga (Num: 895057) it is currently 60.91 Fahrenheit.
#     -----------------------------------
#
#     In Ayagoz (Num: 1525988) it is currently 63.57 Fahrenheit.
#     -----------------------------------
#
#     In Stoughton (Num: 4952206) it is currently 53.67 Fahrenheit.
#     -----------------------------------
#
#     In Kansanshi (Num: 913613) it is currently 53.04 Fahrenheit.
#     -----------------------------------
#
#     In Labuan (Num: 1733782) it is currently 82.2 Fahrenheit.
#     -----------------------------------
#
#     In Bereda (Num: 3105522) it is currently 55.31 Fahrenheit.
#     -----------------------------------
#
#     In Abbeville (Num: 3038789) it is currently 47.5 Fahrenheit.
#     -----------------------------------
#
#     In Port Macquarie (Num: 2152659) it is currently 66.94 Fahrenheit.
#     -----------------------------------
#
#     In Srīvardhan (Num: 1255619) it is currently 94.48 Fahrenheit.
#     -----------------------------------
#
#     jujuy was not found.
#     -----------------------------------
#
#     In Kouango (Num: 2385535) it is currently 70.72 Fahrenheit.
#     -----------------------------------
#
#     In Alihe (Num: 2038665) it is currently 58.39 Fahrenheit.
#     -----------------------------------
#
#     In Segezha (Num: 497927) it is currently 49.42 Fahrenheit.
#     -----------------------------------
#
#     In Kargasok (Num: 1504382) it is currently 66.13 Fahrenheit.
#     -----------------------------------
#
#     In Jaqué (Num: 3708432) it is currently 79.88 Fahrenheit.
#     -----------------------------------
#
#     In Coahuayana Viejo (Num: 4013679) it is currently 77.13 Fahrenheit.
#     -----------------------------------
#
#     In Seoul (Num: 1835848) it is currently 70.92 Fahrenheit.
#     -----------------------------------
#
#     In Redding (Num: 5570160) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Elmira (Num: 5116497) it is currently 42.6 Fahrenheit.
#     -----------------------------------
#
#     In Cheyenne (Num: 5821086) it is currently 45.07 Fahrenheit.
#     -----------------------------------
#
#     In Galle (Num: 1246294) it is currently 84.34 Fahrenheit.
#     -----------------------------------
#
#     In Pouébo (Num: 2138607) it is currently 79.21 Fahrenheit.
#     -----------------------------------
#
#     In Skarnes (Num: 3139244) it is currently 47.71 Fahrenheit.
#     -----------------------------------
#
#     In Inuvik (Num: 5983607) it is currently 46.4 Fahrenheit.
#     -----------------------------------
#
#     In Kibre Mengist (Num: 333103) it is currently 63.59 Fahrenheit.
#     -----------------------------------
#
#     In São João da Barra (Num: 3448903) it is currently 68.79 Fahrenheit.
#     -----------------------------------
#
#     In Townsville (Num: 2146142) it is currently 80.6 Fahrenheit.
#     -----------------------------------
#
#     In Ourém (Num: 2265388) it is currently 50.2 Fahrenheit.
#     -----------------------------------
#
#     In Morant Bay (Num: 3489440) it is currently 76.21 Fahrenheit.
#     -----------------------------------
#
#     In Mildura (Num: 2157698) it is currently 59.97 Fahrenheit.
#     -----------------------------------
#
#     In Adeje (Num: 2522437) it is currently 61.48 Fahrenheit.
#     -----------------------------------
#
#     In Bubaque (Num: 2374583) it is currently 76.73 Fahrenheit.
#     -----------------------------------
#
#     In Southampton (Num: 2637487) it is currently 48.67 Fahrenheit.
#     -----------------------------------
#
#     In Zhigansk (Num: 2012530) it is currently 52.45 Fahrenheit.
#     -----------------------------------
#
#     In Canutama (Num: 3664716) it is currently 72.5 Fahrenheit.
#     -----------------------------------
#
#     In Udaipura (Num: 1253984) it is currently 102.79 Fahrenheit.
#     -----------------------------------
#
#     In Mercedes (Num: 3430708) it is currently 46.69 Fahrenheit.
#     -----------------------------------
#
#     In Svarstad (Num: 7626348) it is currently 49.24 Fahrenheit.
#     -----------------------------------
#
#     In Kahului (Num: 5847411) it is currently 72.52 Fahrenheit.
#     -----------------------------------
#
#     In Tecpan (Num: 3588476) it is currently 57.87 Fahrenheit.
#     -----------------------------------
#
#     bolungarvik was not found.
#     -----------------------------------
#
#     In Guozhen (Num: 1809263) it is currently 57.4 Fahrenheit.
#     -----------------------------------
#
#     nguiu was not found.
#     -----------------------------------
#
#     In Takoradze (Num: 2294915) it is currently 79.81 Fahrenheit.
#     -----------------------------------
#
#     In Fare (Num: 4034496) it is currently 82.24 Fahrenheit.
#     -----------------------------------
#
#     In Linjiang (Num: 2036069) it is currently 68.9 Fahrenheit.
#     -----------------------------------
#
#     In Flinders (Num: 6255012) it is currently 62.58 Fahrenheit.
#     -----------------------------------
#
#     In Pringsewu (Num: 1630639) it is currently 89.2 Fahrenheit.
#     -----------------------------------
#
#     In Noumea (Num: 2139521) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Bambous Virieux (Num: 1106677) it is currently 77.95 Fahrenheit.
#     -----------------------------------
#     In Marsh Harbour (Num: 3571913) it is currently 76.66 Fahrenheit.
#     -----------------------------------
#
#     guajara-mirim was not found.
#     -----------------------------------
#
#     In Rincon (Num: 4218882) it is currently 53.6 Fahrenheit.
#     -----------------------------------
#
#     In Pangnirtung (Num: 6096551) it is currently 21.29 Fahrenheit.
#     -----------------------------------
#
#     sorvag was not found.
#     -----------------------------------
#
#     In Karratha (Num: 6620339) it is currently 84.4 Fahrenheit.
#     -----------------------------------
#
#     In Udachny (Num: 2014624) it is currently 35.51 Fahrenheit.
#     -----------------------------------
#
#     In Karachi (Num: 1174872) it is currently 89.6 Fahrenheit.
#     -----------------------------------
#
#     In Waddān (Num: 2209055) it is currently 74.08 Fahrenheit.
#     -----------------------------------
#
#     In La Ronge (Num: 6050066) it is currently 43.7 Fahrenheit.
#     -----------------------------------
#
#     In Billings Metropolitan Area (Num: 5640350) it is currently 52.21 Fahrenheit.
#     -----------------------------------
#
#     In Iquitos (Num: 3696183) it is currently 75.2 Fahrenheit.
#     -----------------------------------
#
#     In Minapasuk (Num: 1680505) it is currently 85.08 Fahrenheit.
#     -----------------------------------
#
#     In Bambari (Num: 240604) it is currently 70.16 Fahrenheit.
#     -----------------------------------
#
#     fort saint john was not found.
#     -----------------------------------
#
#     In Guadalajara (Num: 4005539) it is currently 73.42 Fahrenheit.
#     -----------------------------------
#
#     In Evensk (Num: 2125693) it is currently 33.06 Fahrenheit.
#     -----------------------------------
#
#     In Shenjiamen (Num: 1795632) it is currently 71.06 Fahrenheit.
#     -----------------------------------
#
#     In Liaozhong (Num: 2036106) it is currently 57.2 Fahrenheit.
#     -----------------------------------
#
#     In Mastic Beach (Num: 5126209) it is currently 58.51 Fahrenheit.
#     -----------------------------------
#
#     In Matagami (Num: 6067747) it is currently 48.2 Fahrenheit.
#     -----------------------------------
#
#     In Methóni (Num: 257122) it is currently 58.48 Fahrenheit.
#     -----------------------------------
#
#     In Hervey Bay (Num: 2146219) it is currently 77 Fahrenheit.
#     -----------------------------------
#
#     In Ermelo (Num: 1005125) it is currently 44.02 Fahrenheit.
#     -----------------------------------
#
#     In Nantucket (Num: 4944903) it is currently 53.33 Fahrenheit.
#     -----------------------------------
#
#     In Mayumba (Num: 2399001) it is currently 77.25 Fahrenheit.
#     -----------------------------------
#
#     In Olafsvik (Num: 3414079) it is currently 38.8 Fahrenheit.
#     -----------------------------------
#
#     In Onega (Num: 515246) it is currently 54.64 Fahrenheit.
#     -----------------------------------
#
#     In Fukuechō (Num: 1863997) it is currently 71.6 Fahrenheit.
#     -----------------------------------
#
#     In Malazgirt (Num: 304916) it is currently 65.79 Fahrenheit.
#     -----------------------------------
#
#     In Jumla (Num: 1283285) it is currently 67.39 Fahrenheit.
#     -----------------------------------
#
#     In Sampit (Num: 1628884) it is currently 87.15 Fahrenheit.
#     -----------------------------------
#
#     In Pacifica (Num: 5380420) it is currently 50.02 Fahrenheit.
#     -----------------------------------
#
#     In Santa Cruz de la Sierra (Num: 3904906) it is currently 67.01 Fahrenheit.
#     -----------------------------------
#
#     In San Cristobal (Num: 3628473) it is currently 78.8 Fahrenheit.
#     -----------------------------------
#
#     In Lujiang (Num: 1802068) it is currently 71.82 Fahrenheit.
#     -----------------------------------
#
#     In Scarborough (Num: 2638419) it is currently 45.61 Fahrenheit.
#     -----------------------------------
#
#     palabuhanratu was not found.
#     -----------------------------------
#
#     In Bokhan (Num: 2026544) it is currently 55.06 Fahrenheit.
#     -----------------------------------
#
#     In Amahai (Num: 1651591) it is currently 82 Fahrenheit.
#     -----------------------------------
#
#     In Kununurra (Num: 2068110) it is currently 86 Fahrenheit.
#     -----------------------------------
#
#     In Gimli (Num: 5961417) it is currently 55.4 Fahrenheit.
#     -----------------------------------
#
#     In Oranjemund (Num: 3354071) it is currently 60.04 Fahrenheit.
#     -----------------------------------
#
#     In Caucayá (Num: 3671437) it is currently 71.4 Fahrenheit.
#     -----------------------------------
#
#     In Japura (Num: 1642773) it is currently 87.26 Fahrenheit.
#     -----------------------------------
#
#     In Skjervøy (Num: 777682) it is currently 38.32 Fahrenheit.
#     -----------------------------------
#
#     In Nadym (Num: 1498087) it is currently 36.82 Fahrenheit.
#     -----------------------------------
#
#     barawe was not found.
#     -----------------------------------
#
#     In Laurel (Num: 4360369) it is currently 50.95 Fahrenheit.
#     -----------------------------------
#
#     In Antofagasta (Num: 3899539) it is currently 60.8 Fahrenheit.
#     -----------------------------------
#
#     In Shimanovsk (Num: 2016701) it is currently 42.98 Fahrenheit.
#     -----------------------------------
#
#     In Inhambane (Num: 1045114) it is currently 66.09 Fahrenheit.
#     -----------------------------------
#
#     In Turbat (Num: 1163054) it is currently 100.22 Fahrenheit.
#     -----------------------------------
#
#     ho was not found.
#     -----------------------------------
#
#     In Suntar (Num: 2015913) it is currently 64.92 Fahrenheit.
#     -----------------------------------
#
#     In Fairbanks (Num: 5861897) it is currently 56.97 Fahrenheit.
#     -----------------------------------
#
#     In Talnakh (Num: 1490256) it is currently 22.37 Fahrenheit.
#     -----------------------------------
#
#     In Ingleside (Num: 4700033) it is currently 74.88 Fahrenheit.
#     -----------------------------------
#
#     In Znamenskoye (Num: 1485020) it is currently 79.66 Fahrenheit.
#     -----------------------------------
#
#     In Hondomachi-hondo (Num: 1862230) it is currently 72.19 Fahrenheit.
#     -----------------------------------
#
#     In Sakaiminato (Num: 1853174) it is currently 84.2 Fahrenheit.
#     -----------------------------------
#
#     In Kisi (Num: 2334327) it is currently 74.57 Fahrenheit.
#     -----------------------------------
#
#     In Laguna (Num: 5364271) it is currently 58.82 Fahrenheit.
#     -----------------------------------
#
#     In Guabito (Num: 3708989) it is currently 75.6 Fahrenheit.
#     -----------------------------------
#
#     In Marsá Maţrūḩ (Num: 352733) it is currently 62.6 Fahrenheit.
#     -----------------------------------
#
#     In Havøysund (Num: 779622) it is currently 35.6 Fahrenheit.
#     -----------------------------------
#
#     In Utuado (Num: 4568490) it is currently 71.37 Fahrenheit.
#     -----------------------------------
#
#     In Río Gallegos (Num: 3838859) it is currently 48.2 Fahrenheit.
#     -----------------------------------
#
#     In Alta Floresta (Num: 6316343) it is currently 70.05 Fahrenheit.
#     -----------------------------------
#
#     In Katherine (Num: 2068655) it is currently 86 Fahrenheit.
#     -----------------------------------
#
#     In Sobolevo (Num: 525426) it is currently 56.12 Fahrenheit.
#     -----------------------------------
#
#     In Tual (Num: 1623197) it is currently 83.37 Fahrenheit.
#     -----------------------------------
#
#     In Timbiquí (Num: 3667070) it is currently 73.87 Fahrenheit.
#     -----------------------------------
#
#     In Yarensk (Num: 468983) it is currently 63.77 Fahrenheit.
#     -----------------------------------
#
#     In Yuncheng (Num: 1785738) it is currently 62.89 Fahrenheit.
#     -----------------------------------
#
#     In Road Town (Num: 3577430) it is currently 79.34 Fahrenheit.
#     -----------------------------------
#
#     In Kenora (Num: 5991056) it is currently 53.29 Fahrenheit.
#     -----------------------------------
#
#     In Kaitangata (Num: 2208248) it is currently 48 Fahrenheit.
#     -----------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#exporting to csv
weather_df.to_csv('Weather Check.csv')

# %%
#calling df
weather_df.head()
# Out:
#         City  Temperature (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)  \
# 0    Rikitea            75.25          63.0            96.0             22.24
# 1     Albany            49.66          55.0            25.0              4.45
# 2       Lebu            52.21          92.0             7.0              6.60
# 3     Bethel            53.92          66.0            20.0              3.06
# 4  Manturovo            61.11          90.0            98.0              5.97
#
#    Lat  Lon
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are cities with humidity over 100%
humid_df = weather_df[weather_df['Humidity (%)']>100]
humid_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Temperature (F), Humidity (%), Cloudiness (%), Wind Speed (mph), Lat, Lon]
# Index: []

# %%
humid_df_2 = weather_df.sort_values('Humidity (%)', ascending = False)
humid_df_2
# Out:
#                  City  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 949             Ancud            42.98         100.0            20.0
# 535           Skarnes            47.70         100.0            90.0
# 818           Horsham            47.21         100.0            75.0
# 1387          Lujiang            71.82         100.0            20.0
# 1197        Bolshevik            53.31         100.0            75.0
# ...               ...              ...           ...             ...
# 1356           sorvag              NaN           NaN             NaN
# 1366  fort saint john              NaN           NaN             NaN
# 1389    palabuhanratu              NaN           NaN             NaN
# 1399           barawe              NaN           NaN             NaN
# 1405               ho              NaN           NaN             NaN
#
#       Wind Speed (mph)      Lat       Lon
# 949               3.44 -41.8697  -73.8203
# 535               5.75      NaN       NaN
# 818               4.61  51.0640   -0.3272
# 1387             11.18  31.2581  117.2817
# 1197              4.47  54.0065   27.5692
# ...                ...      ...       ...
# 1356               NaN      NaN       NaN
# 1366               NaN      NaN       NaN
# 1389               NaN      NaN       NaN
# 1399               NaN      NaN       NaN
# 1405               NaN      NaN       NaN
#
# [1430 rows x 7 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

##No instances where humidity is over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

##No instances where humidity is over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
len(weather_df['Temperature (F)'])
# Out:
# 641

# %%
fig, ax = plt.subplots();
ax.scatter(weather_df['Lat'], weather_df['Temperature (F)']);
ax.set(title = "Latitude vs. Temperature Plot",
      xlabel = "City Latitude",
      ylabel = 'Temperature (F)');
plt.savefig('Latitude vs. Temperature Plot.png', bbox_inches='tight');

# %% [markdown]
# This plot is analyzing the relationship between a city's temperature and latitde. Based on the plot produced, it seems that temperature seems to be lower in cities where the latitude is either very high or very low meaning the farther away from the equator a city is, the colder it will be.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig2, ax2 = plt.subplots();
ax2.scatter(weather_df['Lat'], weather_df['Humidity (%)']);
ax2.set(title = "Latitude vs. Humidity Plot",
      xlabel = "City Latitude",
      ylabel = 'Humidity (%)');
plt.savefig('Latitude vs. Humidity Plot.png', bbox_inches='tight')

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitde. Based on the plot produced, it seems that there is no apparent pattern in the way latitude is related to humidity. However, from the cities within our data frame, it seems humidity tends to be relatively high.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig3, ax3 = plt.subplots();
ax3.scatter(weather_df['Lat'], weather_df['Cloudiness (%)']);
ax3.set(title = "Latitude vs. Cloudiness Plot",
      xlabel = "City Latitude",
      ylabel = 'Cloudiness (%)');
plt.savefig('Latitude vs. Cloudiness Plot.png', bbox_inches='tight')

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitde. Based on the plot produced, it seems that there is no apparent pattern in the way latitude is related to cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig4, ax4 = plt.subplots();
ax4.scatter(weather_df['Lat'], weather_df['Wind Speed (mph)']);
ax4.set(title = "Latitude vs. Wind Speed Plot",
      xlabel = "City Latitude",
      ylabel = 'Wind Speed (mph)');
plt.savefig('Latitude vs. Wind Speed Plot.png', bbox_inches='tight')

# %% [markdown]
# This plot is analyzing the relationship between a city's wind speed and latitde. Based on the plot produced, it seems that there is no apparent pattern in the way latitude is related to wind speed. However, from the cities within our data frame, it seems wind speeds tend to be relatively low.

# %% [markdown]
# ## Linear Regression

# %%
northern = weather_df[weather_df['Lat']>=0]
southern = weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Temperature (F)'])
regress_values = northern['Lat'] *slope + intercept
fig5, ax5 = plt.subplots()
ax5.scatter(northern['Lat'], northern['Temperature (F)'])
ax5.set(title = "Latitude vs Temperature Plot for Northern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Temperature (F)");
ax5.plot(northern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Temperature Plot for Northern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.669504054165301

# %% [markdown]
# This plot is analyzing the relationship between a city's temperature and latitde where the city is within the Norther Hemisphere. Based on the plot produced, it seems that temperature seems to be lower in cities where the latitude is higher and therefore implying that the farther away from the equator a city is, the colder it will be. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Temperature (F)'])
regress_values = southern['Lat'] *slope + intercept
fig6, ax6 = plt.subplots()
ax6.scatter(southern['Lat'], southern['Temperature (F)'])
ax6.set(title = "Latitude vs Temperature Plot for Southern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Temperature (F)");
ax6.plot(southern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Temperature Plot for Southern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.5961438491752807

# %% [markdown]
# This plot is analyzing the relationship between a city's temperature and latitde where the city is within the Southern Hemisphere. Based on the plot produced, it seems that temperature seems to be lower in cities where the latitude is lower and therefore implying that the farther away from the equator a city is, the colder it will be. Our r value confirms this.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Humidity (%)'])
regress_values = northern['Lat'] *slope + intercept
fig7, ax7 = plt.subplots()
ax7.scatter(northern['Lat'], northern['Humidity (%)'])
ax7.set(title = "Latitude vs Humidity Plot for Northern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Humidity (%)");
ax7.plot(northern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Humidity Plot for Northern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0024056028822549338

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitde where the city is in the Northern Hemisphere. Based on the plot produced, it seems that there is no apparent pattern in the way latitude is related to humidity. Our r value confirms this.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Humidity (%)'])
regress_values = southern['Lat'] *slope + intercept
fig6, ax6 = plt.subplots()
ax6.scatter(southern['Lat'], southern['Humidity (%)'])
ax6.set(title = "Latitude vs Humidity Plot for Northern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Humidity (%)");
ax6.plot(southern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Humidity Plot for Southern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.05812950022329976

# %% [markdown]
# This plot is analyzing the relationship between a city's humidity and latitde where the city is in the Southern Hemisphere. Based on the plot produced, it seems that there is a vary faint positive relation between humidity and latitude however it is not a strong relationship, which is confirmed by our r value. I would argue that the two variables are pretty much unrelated.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Cloudiness (%)'])
regress_values = northern['Lat'] *slope + intercept
fig9, ax9 = plt.subplots()
ax9.scatter(northern['Lat'], northern['Cloudiness (%)'])
ax9.set(title = "Latitude vs Cloudiness Plot for Northern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Cloudiness (%)");
ax9.plot(northern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Cloudiness Plot for Northern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.059940287868888664

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitde where the city is within the Northern Hemisphere. Our r value suggests a very weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Cloudiness (%)'])
regress_values = southern['Lat'] *slope + intercept
fig8, ax8 = plt.subplots()
ax8.scatter(southern['Lat'], southern['Cloudiness (%)'])
ax8.set(title = "Latitude vs Cloudiness Plot for Southern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Cloudiness (%)");
ax8.plot(southern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Cloudiness Plot for Southern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.013883792217266143

# %% [markdown]
# This plot is analyzing the relationship between a city's cloudiness and latitde where the city is within the Southern Hemisphere. Our r value suggests a very weak positive relationship between latitude and cloudiness. I would argue that there is no relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern['Lat'], northern['Wind Speed (mph)'])
regress_values = northern['Lat'] *slope + intercept
fig11, ax11 = plt.subplots()
ax11.scatter(northern['Lat'], northern['Wind Speed (mph)'])
ax11.set(title = "Latitude vs Wind Speed Plot for Northern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Wind Speed (mph)");
ax11.plot(northern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Wind Speed Plot for Northern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.0001447879434049455

# %% [markdown]
# This plot is analyzing the relationship between a city's wind speeds and latitde where the city is in the Northern Hemisphere. Based on the plot produced, it seems that there is no apparent pattern in the way latitude is related to wind speed. Our r confirms this analysis.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern['Lat'], southern['Wind Speed (mph)'])
regress_values = southern['Lat'] *slope + intercept
fig8, ax8 = plt.subplots()
ax8.scatter(southern['Lat'], southern['Wind Speed (mph)'])
ax8.set(title = "Latitude vs Wind Speed Plot for Southern Hemisphere", 
       xlabel = "Latitude", 
       ylabel = "Wind Speed (mph)");
ax8.plot(southern['Lat'], regress_values, "r-");
print(f"The r-squared is: {rvalue**2}")
plt.savefig('Latitude vs. Wind Speed Plot for Southern Hemisphere.png', bbox_inches='tight')
# Out:
# The r-squared is: 0.047613580672765735

# %% [markdown]
# This plot is analyzing the relationship between a city's wind speeds and latitde where the city is in the Southern Hemisphere. Based on the plot produced, it seems that there is a very weak negative relationship between latitude and wind speed. Our r value confirms this however, I would argue that there is no apparent pattern in the way latitude is related to wind speed.
